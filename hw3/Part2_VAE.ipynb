# %% [markdown]
# $$
# \newcommand{\mat}[1]{\boldsymbol {#1}}
# \newcommand{\mattr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\matinv}[1]{\boldsymbol {#1}^{-1}}
# \newcommand{\vec}[1]{\boldsymbol {#1}}
# \newcommand{\vectr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\rvar}[1]{\mathrm {#1}}
# \newcommand{\rvec}[1]{\boldsymbol{\mathrm{#1}}}
# \newcommand{\diag}{\mathop{\mathrm {diag}}}
# \newcommand{\set}[1]{\mathbb {#1}}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\pderiv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\bm}[1]{{\bf #1}}
# \newcommand{\bb}[1]{\bm{\mathrm{#1}}}
# $$
#
# # Part 2: Variational Autoencoder
# <a id=part2></a>

# %% [markdown]
# In this part we will learn to generate new data using a special type of autoencoder model which allows us to
# sample from its latent space. We'll implement and train a VAE and use it to generate new images.

# %%
import unittest
import os
import sys
import pathlib
import urllib
import shutil
import re
import zipfile

import numpy as np
import torch
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
test = unittest.TestCase()
plt.rcParams.update({'font.size': 12})
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Obtaining the dataset
# <a id=part2_1></a>

# %% [markdown]
# Let's begin by downloading a dataset of images that we want to learn to generate.
# We'll use the [Labeled Faces in the Wild](http://vis-www.cs.umass.edu/lfw/) (LFW) dataset which contains many labeled faces of famous individuals.
#
# We're going to train our generative model to generate a specific face, not just any face.
# Since the person with the most images in this dataset is former president George W. Bush, we'll set out to train a Bush Generator :)
#
# However, if you feel adventurous and/or prefer to generate something else, feel free to edit the `PART2_CUSTOM_DATA_URL` variable in `hw3/answers.py`.

# %%
import cs236781.plot as plot
import cs236781.download
from hw3.answers import PART2_CUSTOM_DATA_URL as CUSTOM_DATA_URL

DATA_DIR = pathlib.Path.home().joinpath('.pytorch-datasets')
if CUSTOM_DATA_URL is None:
    DATA_URL = 'http://vis-www.cs.umass.edu/lfw/lfw-bush.zip'
else:
    DATA_URL = CUSTOM_DATA_URL

_, dataset_dir = cs236781.download.download_data(out_path=DATA_DIR, url=DATA_URL, extract=True, force=False)
# Out:
# Downloading http://vis-www.cs.umass.edu/lfw/lfw-bush.zip...
# Saved to C:\Users\Eliran\.pytorch-datasets\lfw-bush.zip.
# Extracting C:\Users\Eliran\.pytorch-datasets\lfw-bush.zip...
# Extracted 531 to C:\Users\Eliran\.pytorch-datasets\lfw/George_W_Bush

# %% [markdown]
# Create a `Dataset` object that will load the extraced images:

# %%
import torchvision.transforms as T
from torchvision.datasets import ImageFolder

im_size = 64
tf = T.Compose([
    # Resize to constant spatial dimensions
    T.Resize((im_size, im_size)),
    # PIL.Image -> torch.Tensor
    T.ToTensor(),
    # Dynamic range [0,1] -> [-1, 1]
    T.Normalize(mean=(.5,.5,.5), std=(.5,.5,.5)),
])

ds_gwb = ImageFolder(os.path.dirname(dataset_dir), tf)

# %% [markdown]
# OK, let's see what we got. You can run the following block multiple times to display a random subset of images from the dataset.

# %%
_ = plot.dataset_first_n(ds_gwb, 50, figsize=(15,10), nrows=5)
print(f'Found {len(ds_gwb)} images in dataset folder.')
# Out:
# Found 530 images in dataset folder.

# %%
x0, y0 = ds_gwb[0]
x0 = x0.unsqueeze(0).to(device)
print(x0.shape)

test.assertSequenceEqual(x0.shape, (1, 3, im_size, im_size))
# Out:
# torch.Size([1, 3, 64, 64])

# %% [markdown]
# ## The Variational Autoencoder
# <a id=part2_2></a>

# %% [markdown]
# An autoencoder is a model which learns a representation of data in an **unsupervised** fashion (i.e without any labels).
# Recall it's general form from the lecture:
#
# <img src="imgs/autoencoder.jpg"/>

# %% [markdown]
# An autoencoder maps an instance $\bb{x}$ to a **latent-space** representation $\bb{z}$.
# It has an encoder part, $\Phi_{\bb{\alpha}}(\bb{x})$ (a model with parameters $\bb{\alpha}$)
# and a decoder part, $\Psi_{\bb{\beta}}(\bb{z})$ (a model with parameters $\bb{\beta}$).
#
# While autoencoders can learn useful representations,
# generally it's hard to use them as generative models because there's no distribution we can sample from in the latent space. In other words, we have no way to choose a point $\bb{z}$ in the latent space
# such that $\Psi(\bb{z})$ will end up on the data manifold in the instance space.
#
# <img src="imgs/ae_sampling.jpg"/>

# %% [markdown]
# The variational autoencoder (VAE), first proposed by [Kingma and Welling](https://arxiv.org/pdf/1312.6114.pdf), addresses this issue by taking a probabilistic perspective.
# Briefly, a VAE model can be described as follows.
#
# We define, in Baysean terminology,
# - The **prior** distribution $p(\bb{Z})$ on points in the latent space.
# - The **posterior** distribution of points in the latent spaces given a specific instance: $p(\bb{Z}|\bb{X})$.
# - The **likelihood** distribution of a sample $\bb{X}$ given a latent-space representation: $p(\bb{X}|\bb{Z})$.
# - The **evidence** distribution $p(\bb{X})$ which is the distribution of the instance space due to the generative process.

# %% [markdown]
# To create our variational **decoder** we'll further specify:
#
# - A parametric likelihood distribution, $p _{\bb{\beta}}(\bb{X} | \bb{Z}=\bb{z}) = \mathcal{N}( \Psi _{\bb{\beta}}(\bb{z}) , \sigma^2 \bb{I} )$. The interpretation is that given a latent $\bb{z}$, we map it to a point normally distributed around the point calculated by our decoder neural network. Note that here $\sigma^2$ is a hyperparameter while $\vec{\beta}$ represents the network parameters.
# - A fixed latent-space prior distribution of $p(\bb{Z}) = \mathcal{N}(\bb{0},\bb{I})$.
#
# This setting allows us to generate a new instance $\bb{x}$ by sampling $\bb{z}$ from the multivariate normal
# distribution, obtaining the instance-space mean $\Psi _{\bb{\beta}}(\bb{z})$ using our decoder network,
# and then sampling $\bb{x}$ from $\mathcal{N}( \Psi _{\bb{\beta}}(\bb{z}) , \sigma^2 \bb{I} )$.

# %% [markdown]
# Our variational **encoder** will approximate the posterior with a parametric distribution
# $q _{\bb{\alpha}}(\bb{Z} | \bb{x}) =
# \mathcal{N}( \bb{\mu} _{\bb{\alpha}}(\bb{x}),  \mathrm{diag}\{ \bb{\sigma}^2_{\bb{\alpha}}(\bb{x}) \} )$.
# The interpretation is that our encoder model, $\Phi_{\vec{\alpha}}(\bb{x})$, calculates
# the mean and variance of the posterior distribution, and samples $\bb{z}$ based on them.
# An important nuance here is that our network can't contain any stochastic elements that
# depend on the model parameters, otherwise we won't be able to back-propagate to those parameters.
# So sampling $\bb{z}$ from $\mathcal{N}( \bb{\mu} _{\bb{\alpha}}(\bb{x}),  \mathrm{diag}\{ \bb{\sigma}^2_{\bb{\alpha}}(\bb{x}) \} )$ is not an option.
# The solution is to use what's known as the **reparametrization trick**: sample from an isotropic Gaussian,
# i.e. $\bb{u}\sim\mathcal{N}(\bb{0},\bb{I})$ (which doesn't depend on trainable parameters), and calculate the latent representation as
# $\bb{z} = \bb{\mu} _{\bb{\alpha}}(\bb{x}) + \bb{u}\odot\bb{\sigma}_{\bb{\alpha}}(\bb{x})$.

# %% [markdown]
# To train a VAE model, we maximize the evidence distribution, $p(\bb{X})$ (see question below).
# The **VAE loss** can therefore be stated as minimizing $\mathcal{L} = -\mathbb{E}_{\bb{x}} \log p(\bb{X})$.
# Although this expectation is intractable,
# we can obtain a lower-bound for $p(\bb{X})$ (the evidence lower bound, "ELBO", shown in the lecture):
#
# $$
# \log p(\bb{X}) \ge \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }\left[ \log  p _{\bb{\beta}}(\bb{X} | \bb{z}) \right]
# -  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{X})\,\left\|\, p(\bb{Z} )\right.\right)
# $$
#
# where
# $
# \mathcal{D} _{\mathrm{KL}}(q\left\|\right.p) =
# \mathbb{E}_{\bb{z}\sim q}\left[ \log \frac{q(\bb{Z})}{p(\bb{Z})} \right]
# $
# is the Kullback-Liebler divergence, which can be interpreted as the information gained by using the posterior $q(\bb{Z|X})$ instead of the prior distribution $p(\bb{Z})$.
#
# Using the ELBO, the VAE loss becomes,
# $$
# \mathcal{L}(\vec{\alpha},\vec{\beta}) = \mathbb{E} _{\bb{x}}  \left[
# \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }\left[ -\log  p _{\bb{\beta}}(\bb{x} | \bb{z}) \right]
# +  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{x})\,\left\|\, p(\bb{Z} )\right.\right)
# \right].
# $$
#
# By remembering that the likelihood is a Gaussian distribution with a diagonal covariance and by applying the reparametrization trick, we can write the above as
#
# $$
# \mathcal{L}(\vec{\alpha},\vec{\beta}) = \mathbb{E} _{\bb{x}}  \left[
# \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }
# \left[
# \frac{1}{2\sigma^2}\left\| \bb{x}- \Psi _{\bb{\beta}}\left(  \bb{\mu} _{\bb{\alpha}}(\bb{x})  + \bb{\Sigma}^{\frac{1}{2}} _{\bb{\alpha}}(\bb{x}) \bb{u}   \right) \right\| _2^2
# \right]
# +  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{x})\,\left\|\, p(\bb{Z} )\right.\right)
# \right].
# $$

# %% [markdown]
# ### Model Implementation
# <a id=part2_3></a>

# %% [markdown]
# Obviously our model will have two parts, an encoder and a decoder.
# Since we're working with images, we'll implement both as deep **convolutional** networks, where the decoder is a "mirror image" of the encoder implemented with adjoint (AKA transposed) convolutions.
# Between the encoder CNN and the decoder CNN we'll implement the sampling from
# the parametric posterior approximator $q_{\bb{\alpha}}(\bb{Z}|\bb{x})$
# to make it a VAE model and not just a regular autoencoder (of course, this is not yet enough to create a VAE,
# since we also need a special loss function which we'll get to later).

# %% [markdown]
# First let's implement just the CNN part of the Encoder network
# (this is not the full $\Phi_{\vec{\alpha}}(\bb{x})$ yet).
# As usual, it should take an input image and map to a activation volume of a specified depth.
# We'll consider this volume as the features we extract from the input image.
# Later we'll use these to create the latent space representation of the input.

# %% [markdown]
# **TODO**: Implement the `EncoderCNN` class in the `hw3/autoencoder.py` module.
# Implement any CNN architecture you like. If you need "architecture inspiration" you can see e.g. [this](https://arxiv.org/pdf/1512.09300.pdf) or [this](https://arxiv.org/pdf/1511.06434.pdf) paper.

# %%
import hw3.autoencoder as autoencoder

in_channels = 3
out_channels = 1024
encoder_cnn = autoencoder.EncoderCNN(in_channels, out_channels).to(device)
print(encoder_cnn)

h = encoder_cnn(x0)
print(h.shape)

test.assertEqual(h.dim(), 4)
test.assertSequenceEqual(h.shape[0:2], (1, out_channels))
# Out:
# EncoderCNN(
#   (cnn): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (4): ReLU()
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Conv2d(128, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (7): ReLU()
#     (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): Conv2d(256, 1024, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (10): ReLU()
#     (11): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# torch.Size([1, 1024, 4, 4])

# %% [markdown]
# Now let's implement the CNN part of the Decoder.
# Again this is not yet the full $\Psi _{\bb{\beta}}(\bb{z})$. It should take an activation volume produced
# by your `EncoderCNN` and output an image of the same dimensions as the Encoder's input was.
# This can be a CNN which is like a "mirror image" of the the Encoder. For example, replace convolutions with transposed convolutions, downsampling with up-sampling etc.
# Consult the documentation of [ConvTranspose2D](https://pytorch.org/docs/0.4.1/nn.html#convtranspose2d)
# to figure out how to reverse your convolutional layers in terms of input and output dimensions. Note that the decoder doesn't have to be exactly the opposite of the encoder and you can experiment with using a different architecture.

# %% [markdown]
# **TODO**: Implement the `DecoderCNN` class in the `hw3/autoencoder.py` module.

# %%
decoder_cnn = autoencoder.DecoderCNN(in_channels=out_channels, out_channels=in_channels).to(device)
print(decoder_cnn)
x0r = decoder_cnn(h)
print(x0r.shape)

test.assertEqual(x0.shape, x0r.shape)

# Should look like colored noise
T.functional.to_pil_image(x0r[0].cpu().detach())
# Out:
# DecoderCNN(
#   (cnn): Sequential(
#     (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (1): ReLU()
#     (2): ConvTranspose2d(1024, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): ReLU()
#     (5): ConvTranspose2d(256, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): ConvTranspose2d(128, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): ConvTranspose2d(64, 3, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#   )
# )
# torch.Size([1, 3, 64, 64])
# <PIL.Image.Image image mode=RGB size=64x64 at 0x1B51C2FD130>

# %% [markdown]
# Let's now implement the full VAE Encoder, $\Phi_{\vec{\alpha}}(\vec{x})$.
# It will work as follows:
# 1. Produce a feature vector $\vec{h}$ from the input image $\vec{x}$.
# 2. Use two affine transforms to convert the features into the mean and log-variance of the posterior, i.e.
#     $$
#     \begin{align}
#         \bb{\mu} _{\bb{\alpha}}(\bb{x}) &= \vec{h}\mattr{W}_{\mathrm{h\mu}} + \vec{b}_{\mathrm{h\mu}} \\
#         \log\left(\bb{\sigma}^2_{\bb{\alpha}}(\bb{x})\right) &= \vec{h}\mattr{W}_{\mathrm{h\sigma^2}} + \vec{b}_{\mathrm{h\sigma^2}}
#     \end{align}
#     $$
# 3. Use the **reparametrization trick** to create the latent representation $\vec{z}$.
#
# Notice that we model the **log** of the variance, not the actual variance.
# The above formulation is proposed in appendix C of the [VAE paper](https://arxiv.org/pdf/1312.6114.pdf).

# %% [markdown]
# **TODO**: Implement the `encode()` method in the `VAE` class within the `hw3/autoencoder.py` module.
# You'll also need to define your parameters in `__init__()`.

# %%
z_dim = 2
vae = autoencoder.VAE(encoder_cnn, decoder_cnn, x0[0].size(), z_dim).to(device)
print(vae)

z, mu, log_sigma2 = vae.encode(x0)

test.assertSequenceEqual(z.shape, (1, z_dim))
test.assertTrue(z.shape == mu.shape == log_sigma2.shape)

print(f'mu(x0)={list(*mu.detach().cpu().numpy())}, sigma2(x0)={list(*torch.exp(log_sigma2).detach().cpu().numpy())}')
# Out:
# VAE(
#   (features_encoder): EncoderCNN(
#     (cnn): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (1): ReLU()
#       (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (4): ReLU()
#       (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): Conv2d(128, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (7): ReLU()
#       (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (9): Conv2d(256, 1024, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (10): ReLU()
#       (11): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (features_decoder): DecoderCNN(
#     (cnn): Sequential(
#       (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): ReLU()
#       (2): ConvTranspose2d(1024, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ReLU()
#       (5): ConvTranspose2d(256, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU()
#       (8): ConvTranspose2d(128, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): ReLU()
#       (11): ConvTranspose2d(64, 3, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     )
#   )
#   (mu): Linear(in_features=16384, out_features=2, bias=True)
#   (log_sigma2): Linear(in_features=16384, out_features=2, bias=True)
#   (rec): Linear(in_features=2, out_features=16384, bias=True)
# )
# mu(x0)=[0.20189838, 0.84790903], sigma2(x0)=[0.712638, 1.5060592]

# %% [markdown]
# Let's sample some 2d latent representations for an input image `x0` and visualize them.

# %%
# Sample from q(Z|x)
N = 500
Z = torch.zeros(N, z_dim)
_, ax = plt.subplots()
with torch.no_grad():
    for i in range(N):
        Z[i], _, _ = vae.encode(x0)
        ax.scatter(*Z[i].cpu().numpy())

# Should be close to the mu/sigma in the previous block above
print('sampled mu', torch.mean(Z, dim=0))
print('sampled sigma2', torch.var(Z, dim=0))
# Out:
# sampled mu tensor([0.2424, 0.9027])
# sampled sigma2 tensor([0.4565, 2.3007])

# %% [markdown]
# Let's now implement the full VAE Decoder, $\Psi _{\bb{\beta}}(\bb{z})$.
# It will work as follows:
# 1. Produce a feature vector $\tilde{\vec{h}}$ from the latent vector $\vec{z}$ using an affine transform.
# 2. Reconstruct an image $\tilde{\vec{x}}$ from $\tilde{\vec{h}}$ using the decoder CNN.

# %% [markdown]
# **TODO**: Implement the `decode()` method in the `VAE` class within the `hw3/autoencoder.py` module.
# You'll also need to define your parameters in `__init__()`. You may need to also re-run the block above after you implement this.

# %%
x0r = vae.decode(z)

test.assertSequenceEqual(x0r.shape, x0.shape)

# %% [markdown]
# Our model's `forward()` function will simply return `decode(encode(x))` as well as the calculated mean and log-variance of the posterior.

# %%
x0r, mu, log_sigma2 = vae(x0)

test.assertSequenceEqual(x0r.shape, x0.shape)
test.assertSequenceEqual(mu.shape, (1, z_dim))
test.assertSequenceEqual(log_sigma2.shape, (1, z_dim))
T.functional.to_pil_image(x0r[0].detach().cpu())
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x1B51BE6C640>

# %% [markdown]
# ### Loss Implementation
# <a id=part2_4></a>

# %% [markdown]
# In practice, since we're using SGD, we'll drop the expectation over $\bb{X}$ and instead sample an instance from the training set and compute a point-wise loss. Similarly, we'll drop the expectation over $\bb{Z}$ by sampling from $q_{\vec{\alpha}}(\bb{Z}|\bb{x})$.
# Additionally, because the KL divergence is between two Gaussian distributions, there is a closed-form expression for it. These points bring us to the following point-wise loss:
#
# $$
# \ell(\vec{\alpha},\vec{\beta};\bb{x}) =
# \frac{1}{\sigma^2 d_x} \left\| \bb{x}- \Psi _{\bb{\beta}}\left(  \bb{\mu} _{\bb{\alpha}}(\bb{x})  +
# \bb{\Sigma}^{\frac{1}{2}} _{\bb{\alpha}}(\bb{x}) \bb{u}   \right) \right\| _2^2 +
# \mathrm{tr}\,\bb{\Sigma} _{\bb{\alpha}}(\bb{x}) +  \|\bb{\mu} _{\bb{\alpha}}(\bb{x})\|^2 _2 - d_z - \log\det \bb{\Sigma} _{\bb{\alpha}}(\bb{x}),
# $$
#
# where $d_z$ is the dimension of the latent space, $d_x$ is the dimension of the input and $\bb{u}\sim\mathcal{N}(\bb{0},\bb{I})$.
# This pointwise loss is the quantity that we'll compute and minimize with gradient descent.
# The first term corresponds to the data-reconstruction loss, while the second term corresponds to the KL-divergence loss.
# Note that the scaling by $d_x$ is not derived from the original loss formula and was added directly to the pointwise loss just to normalize the data term.

# %% [markdown]
# **TODO**: Implement the `vae_loss()` function in the `hw3/autoencoder.py` module.

# %%
from hw3.autoencoder import vae_loss
torch.manual_seed(42)

def test_vae_loss():
    # Test data
    N, C, H, W = 10, 3, 64, 64 
    z_dim = 32
    x  = torch.randn(N, C, H, W)*2 - 1
    xr = torch.randn(N, C, H, W)*2 - 1
    z_mu = torch.randn(N, z_dim)
    z_log_sigma2 = torch.randn(N, z_dim)
    x_sigma2 = 0.9
    
    loss, _, _ = vae_loss(x, xr, z_mu, z_log_sigma2, x_sigma2)
    
    test.assertAlmostEqual(loss.item(), 58.3234367, delta=1e-3)
    return loss

test_vae_loss()
# Out:
# tensor(58.3234)

# %% [markdown]
# ### Sampling
# <a id=part2_5></a>

# %% [markdown]
# The main advantage of a VAE is that it can by used as a generative model by sampling the latent space, since
# we optimize for a isotropic Gaussian prior $p(\bb{Z})$ in the loss function. Let's now implement this so that we can visualize how our model is doing when we train.

# %% [markdown]
# **TODO**: Implement the `sample()` method in the `VAE` class within the `hw3/autoencoder.py` module.

# %%
samples = vae.sample(5)
_ = plot.tensors_as_images(samples)

# %% [markdown]
# ### Training
# <a id=part2_6></a>

# %% [markdown]
# Time to train!

# %% [markdown]
# **TODO**:
# 1. Implement the `VAETrainer` class in the `hw3/training.py` module. Make sure to implement the `checkpoints` feature of the `Trainer` class if you haven't done so already in Part 1.
# 2. Tweak the hyperparameters in the `part2_vae_hyperparams()` function within the `hw3/answers.py` module.

# %%
import torch.optim as optim
from torch.utils.data import random_split
from torch.utils.data import DataLoader
from torch.nn import DataParallel
from hw3.training import VAETrainer
from hw3.answers import part2_vae_hyperparams

torch.manual_seed(42)

# Hyperparams
hp = part2_vae_hyperparams()
batch_size = hp['batch_size']
h_dim = hp['h_dim']
z_dim = hp['z_dim']
x_sigma2 = hp['x_sigma2']
learn_rate = hp['learn_rate']
betas = hp['betas']

# Data
split_lengths = [int(len(ds_gwb)*0.9), int(len(ds_gwb)*0.1)]
ds_train, ds_test = random_split(ds_gwb, split_lengths)
dl_train = DataLoader(ds_train, batch_size, shuffle=True)
dl_test  = DataLoader(ds_test,  batch_size, shuffle=True)
im_size = ds_train[0][0].shape

# Model
encoder = autoencoder.EncoderCNN(in_channels=im_size[0], out_channels=h_dim)
decoder = autoencoder.DecoderCNN(in_channels=h_dim, out_channels=im_size[0])
vae = autoencoder.VAE(encoder, decoder, im_size, z_dim)
vae_dp = DataParallel(vae).to(device)

# Optimizer
optimizer = optim.Adam(vae.parameters(), lr=learn_rate, betas=betas)

# Loss
def loss_fn(x, xr, z_mu, z_log_sigma2):
    return autoencoder.vae_loss(x, xr, z_mu, z_log_sigma2, x_sigma2)

# Trainer
trainer = VAETrainer(vae_dp, loss_fn, optimizer, device)
checkpoint_file = 'checkpoints/vae'
checkpoint_file_final = f'{checkpoint_file}_final'
if os.path.isfile(f'{checkpoint_file}.pt'):
    os.remove(f'{checkpoint_file}.pt')

# Show model and hypers
print(vae)
print(hp)
# Out:
# VAE(
#   (features_encoder): EncoderCNN(
#     (cnn): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (1): ReLU()
#       (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (4): ReLU()
#       (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): Conv2d(128, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (7): ReLU()
#       (8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (9): Conv2d(256, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (10): ReLU()
#       (11): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (features_decoder): DecoderCNN(
#     (cnn): Sequential(
#       (0): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (1): ReLU()
#       (2): ConvTranspose2d(512, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (4): ReLU()
#       (5): ConvTranspose2d(256, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (7): ReLU()
#       (8): ConvTranspose2d(128, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#       (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): ReLU()
#       (11): ConvTranspose2d(64, 3, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), output_padding=(1, 1))
#     )
#   )
#   (mu): Linear(in_features=8192, out_features=256, bias=True)
#   (log_sigma2): Linear(in_features=8192, out_features=256, bias=True)
#   (rec): Linear(in_features=256, out_features=8192, bias=True)
# )
# {'batch_size': 8, 'h_dim': 512, 'z_dim': 256, 'x_sigma2': 0.001, 'learn_rate': 0.0001, 'betas': (0.9, 0.99)}

# %% [markdown]
# **TODO**:
# 1. Run the following block to train. It will sample some images from your model every few epochs so you can see the progress.
# 2. When you're satisfied with your results, rename the checkpoints file by adding `_final`. When you run the `main.py` script to generate your submission, the final checkpoints file will be loaded instead of running training. Note that your final submission zip will not include the `checkpoints/` folder. This is OK.
#
# The images you get should be colorful, with different backgrounds and poses.

# %%
import IPython.display

def post_epoch_fn(epoch, train_result, test_result, verbose):
    # Plot some samples if this is a verbose epoch
    if verbose:
        samples = vae.sample(n=5)
        fig, _ = plot.tensors_as_images(samples, figsize=(6,2))
        IPython.display.display(fig)
        plt.close(fig)

if os.path.isfile(f'{checkpoint_file_final}.pt'):
    print(f'*** Loading final checkpoint file {checkpoint_file_final} instead of training')
    checkpoint_file = checkpoint_file_final
else:
    res = trainer.fit(dl_train, dl_test,
                      num_epochs=200, early_stopping=20, print_every=10,
                      checkpoints=checkpoint_file,
                      post_epoch_fn=post_epoch_fn)
    
# Plot images from best model
saved_state = torch.load(f'{checkpoint_file}.pt', map_location=device)
vae_dp.load_state_dict(saved_state['model_state'])
print('*** Images Generated from best model:')
fig, _ = plot.tensors_as_images(vae_dp.module.sample(n=15), nrows=3, figsize=(6,6))
# Out:
# --- EPOCH 1/200 ---
# train_batch (Avg. Loss 385.090, Accuracy 0.0): 100%|███████████████████████████████████| 60/60 [00:06<00:00,  8.87it/s]
# test_batch (Avg. Loss 322.164, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 12.11it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 1
# train_batch (Avg. Loss 273.988, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 17.22it/s]
# test_batch (Avg. Loss 281.868, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 43.12it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 2
# train_batch (Avg. Loss 265.449, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 17.29it/s]
# test_batch (Avg. Loss 271.032, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 47.16it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 3
# train_batch (Avg. Loss 248.073, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 17.22it/s]
# test_batch (Avg. Loss 237.721, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 44.13it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 4
# train_batch (Avg. Loss 230.507, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 17.42it/s]
# test_batch (Avg. Loss 227.775, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 46.87it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 5
# train_batch (Avg. Loss 222.973, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 17.03it/s]
# test_batch (Avg. Loss 220.166, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 47.75it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 6
# train_batch (Avg. Loss 218.386, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.70it/s]
# test_batch (Avg. Loss 228.254, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 43.32it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 7
# train_batch (Avg. Loss 212.418, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.68it/s]
# test_batch (Avg. Loss 214.829, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 41.53it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 8
# train_batch (Avg. Loss 207.518, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.85it/s]
# test_batch (Avg. Loss 213.270, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 44.99it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 9
# train_batch (Avg. Loss 206.029, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 17.00it/s]
# test_batch (Avg. Loss 208.988, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 42.03it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 10
# --- EPOCH 11/200 ---
# train_batch (Avg. Loss 198.435, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.37it/s]
# test_batch (Avg. Loss 204.022, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 41.04it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 11
# train_batch (Avg. Loss 198.301, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 17.22it/s]
# test_batch (Avg. Loss 210.449, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 42.68it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 12
# train_batch (Avg. Loss 196.498, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 17.14it/s]
# test_batch (Avg. Loss 210.452, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 43.74it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 13
# train_batch (Avg. Loss 196.553, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 17.28it/s]
# test_batch (Avg. Loss 198.713, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 47.44it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 14
# train_batch (Avg. Loss 190.141, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 17.29it/s]
# test_batch (Avg. Loss 205.113, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 46.18it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 15
# train_batch (Avg. Loss 192.101, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.56it/s]
# test_batch (Avg. Loss 202.853, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 41.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 16
# train_batch (Avg. Loss 188.883, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.49it/s]
# test_batch (Avg. Loss 191.652, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 44.14it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 17
# train_batch (Avg. Loss 185.329, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.80it/s]
# test_batch (Avg. Loss 196.827, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 43.60it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 18
# train_batch (Avg. Loss 188.574, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.80it/s]
# test_batch (Avg. Loss 192.111, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 42.80it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 19
# train_batch (Avg. Loss 186.438, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.76it/s]
# test_batch (Avg. Loss 189.115, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 46.30it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 20
# --- EPOCH 21/200 ---
# train_batch (Avg. Loss 183.990, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.20it/s]
# test_batch (Avg. Loss 206.725, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 32.63it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 21
# train_batch (Avg. Loss 182.413, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.36it/s]
# test_batch (Avg. Loss 191.569, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 42.28it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 22
# train_batch (Avg. Loss 178.572, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.74it/s]
# test_batch (Avg. Loss 193.889, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.81it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 23
# train_batch (Avg. Loss 179.571, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.72it/s]
# test_batch (Avg. Loss 183.097, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 24
# train_batch (Avg. Loss 175.517, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.79it/s]
# test_batch (Avg. Loss 185.053, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.88it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 25
# train_batch (Avg. Loss 177.042, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.81it/s]
# test_batch (Avg. Loss 186.028, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.35it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 26
# train_batch (Avg. Loss 176.301, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.75it/s]
# test_batch (Avg. Loss 182.353, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.68it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 27
# train_batch (Avg. Loss 174.806, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.83it/s]
# test_batch (Avg. Loss 182.265, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 41.40it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 28
# train_batch (Avg. Loss 172.021, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.78it/s]
# test_batch (Avg. Loss 187.092, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 43.59it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 29
# train_batch (Avg. Loss 175.458, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.76it/s]
# test_batch (Avg. Loss 190.263, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.01it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 30
# --- EPOCH 31/200 ---
# train_batch (Avg. Loss 172.175, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.62it/s]
# test_batch (Avg. Loss 183.132, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.81it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 31
# train_batch (Avg. Loss 169.540, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.40it/s]
# test_batch (Avg. Loss 179.401, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.15it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 32
# train_batch (Avg. Loss 168.798, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.43it/s]
# test_batch (Avg. Loss 180.441, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 33
# train_batch (Avg. Loss 167.649, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.37it/s]
# test_batch (Avg. Loss 186.051, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.18it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 34
# train_batch (Avg. Loss 166.923, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.40it/s]
# test_batch (Avg. Loss 185.241, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.56it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 35
# train_batch (Avg. Loss 168.681, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.32it/s]
# test_batch (Avg. Loss 187.011, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.13it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 36
# train_batch (Avg. Loss 163.084, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.36it/s]
# test_batch (Avg. Loss 171.969, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.68it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 37
# train_batch (Avg. Loss 164.293, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.37it/s]
# test_batch (Avg. Loss 172.381, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.56it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 38
# train_batch (Avg. Loss 163.044, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.30it/s]
# test_batch (Avg. Loss 177.924, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.57it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 39
# train_batch (Avg. Loss 161.535, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.26it/s]
# test_batch (Avg. Loss 172.855, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.89it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 40
# --- EPOCH 41/200 ---
# train_batch (Avg. Loss 160.612, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.36it/s]
# test_batch (Avg. Loss 172.256, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.71it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 41
# train_batch (Avg. Loss 161.347, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.32it/s]
# test_batch (Avg. Loss 178.972, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.74it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 42
# train_batch (Avg. Loss 157.514, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.40it/s]
# test_batch (Avg. Loss 173.445, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 43
# train_batch (Avg. Loss 157.986, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.32it/s]
# test_batch (Avg. Loss 170.459, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 34.75it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 44
# train_batch (Avg. Loss 158.651, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.36it/s]
# test_batch (Avg. Loss 174.171, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.56it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 45
# train_batch (Avg. Loss 159.336, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.23it/s]
# test_batch (Avg. Loss 164.562, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 46
# train_batch (Avg. Loss 157.881, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.38it/s]
# test_batch (Avg. Loss 176.619, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.11it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 47
# train_batch (Avg. Loss 156.341, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.32it/s]
# test_batch (Avg. Loss 164.304, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.33it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 48
# train_batch (Avg. Loss 155.597, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.37it/s]
# test_batch (Avg. Loss 168.681, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.34it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 49
# train_batch (Avg. Loss 154.019, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.35it/s]
# test_batch (Avg. Loss 165.227, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.22it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 50
# --- EPOCH 51/200 ---
# train_batch (Avg. Loss 153.937, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.40it/s]
# test_batch (Avg. Loss 167.608, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.99it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 51
# train_batch (Avg. Loss 152.788, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.08it/s]
# test_batch (Avg. Loss 167.272, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 52
# train_batch (Avg. Loss 149.996, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.32it/s]
# test_batch (Avg. Loss 164.570, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.79it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 53
# train_batch (Avg. Loss 151.354, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.21it/s]
# test_batch (Avg. Loss 168.481, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.05it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 54
# train_batch (Avg. Loss 148.700, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.22it/s]
# test_batch (Avg. Loss 166.571, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.53it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 55
# train_batch (Avg. Loss 151.358, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.28it/s]
# test_batch (Avg. Loss 164.215, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.57it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 56
# train_batch (Avg. Loss 149.706, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.15it/s]
# test_batch (Avg. Loss 157.405, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 57
# train_batch (Avg. Loss 148.642, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.25it/s]
# test_batch (Avg. Loss 160.622, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.88it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 58
# train_batch (Avg. Loss 146.979, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.24it/s]
# test_batch (Avg. Loss 161.647, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.34it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 59
# train_batch (Avg. Loss 148.538, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.16it/s]
# test_batch (Avg. Loss 160.080, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 36.08it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 60
# --- EPOCH 61/200 ---
# train_batch (Avg. Loss 146.083, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.25it/s]
# test_batch (Avg. Loss 156.777, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 36.85it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 61
# train_batch (Avg. Loss 145.924, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.41it/s]
# test_batch (Avg. Loss 159.485, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.67it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 62
# train_batch (Avg. Loss 144.498, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.50it/s]
# test_batch (Avg. Loss 156.402, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.56it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 63
# train_batch (Avg. Loss 146.244, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.44it/s]
# test_batch (Avg. Loss 158.356, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 64
# train_batch (Avg. Loss 143.653, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.38it/s]
# test_batch (Avg. Loss 159.143, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.74it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 65
# train_batch (Avg. Loss 143.798, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.42it/s]
# test_batch (Avg. Loss 161.445, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.15it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 66
# train_batch (Avg. Loss 142.940, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.36it/s]
# test_batch (Avg. Loss 154.611, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.76it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 67
# train_batch (Avg. Loss 141.076, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.43it/s]
# test_batch (Avg. Loss 153.676, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.11it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 68
# train_batch (Avg. Loss 140.426, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.18it/s]
# test_batch (Avg. Loss 160.141, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.53it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 69
# train_batch (Avg. Loss 140.628, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.31it/s]
# test_batch (Avg. Loss 154.783, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.11it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 70
# --- EPOCH 71/200 ---
# train_batch (Avg. Loss 139.209, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.34it/s]
# test_batch (Avg. Loss 158.619, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 36.08it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 71
# train_batch (Avg. Loss 140.367, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.25it/s]
# test_batch (Avg. Loss 154.906, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.35it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 72
# train_batch (Avg. Loss 139.658, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.18it/s]
# test_batch (Avg. Loss 162.691, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 73
# train_batch (Avg. Loss 139.991, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.27it/s]
# test_batch (Avg. Loss 159.710, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.66it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 74
# train_batch (Avg. Loss 138.627, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.17it/s]
# test_batch (Avg. Loss 156.710, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.65it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 75
# train_batch (Avg. Loss 136.693, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.30it/s]
# test_batch (Avg. Loss 159.237, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 76
# train_batch (Avg. Loss 136.962, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.40it/s]
# test_batch (Avg. Loss 150.461, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 36.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 77
# train_batch (Avg. Loss 136.871, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.23it/s]
# test_batch (Avg. Loss 151.122, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 43.72it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 78
# train_batch (Avg. Loss 136.632, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.36it/s]
# test_batch (Avg. Loss 154.415, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.34it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 79
# train_batch (Avg. Loss 137.559, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.43it/s]
# test_batch (Avg. Loss 155.274, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.57it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 80
# --- EPOCH 81/200 ---
# train_batch (Avg. Loss 136.680, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.33it/s]
# test_batch (Avg. Loss 151.024, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.58it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 81
# train_batch (Avg. Loss 134.260, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.37it/s]
# test_batch (Avg. Loss 158.941, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.61it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 82
# train_batch (Avg. Loss 134.939, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.46it/s]
# test_batch (Avg. Loss 150.883, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 83
# train_batch (Avg. Loss 133.750, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.45it/s]
# test_batch (Avg. Loss 148.299, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.35it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 84
# train_batch (Avg. Loss 134.414, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.38it/s]
# test_batch (Avg. Loss 150.410, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.21it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 85
# train_batch (Avg. Loss 134.613, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.51it/s]
# test_batch (Avg. Loss 150.774, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.15it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 86
# train_batch (Avg. Loss 133.542, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.42it/s]
# test_batch (Avg. Loss 148.231, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.65it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 87
# train_batch (Avg. Loss 134.720, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.43it/s]
# test_batch (Avg. Loss 157.106, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.03it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 88
# train_batch (Avg. Loss 132.783, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.25it/s]
# test_batch (Avg. Loss 151.412, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.07it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 89
# train_batch (Avg. Loss 132.843, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.38it/s]
# test_batch (Avg. Loss 147.326, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.34it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 90
# --- EPOCH 91/200 ---
# train_batch (Avg. Loss 131.802, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.29it/s]
# test_batch (Avg. Loss 147.350, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.88it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 91
# train_batch (Avg. Loss 131.898, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.40it/s]
# test_batch (Avg. Loss 146.265, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.57it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 92
# train_batch (Avg. Loss 131.404, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.37it/s]
# test_batch (Avg. Loss 149.880, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.03it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 93
# train_batch (Avg. Loss 131.528, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.42it/s]
# test_batch (Avg. Loss 154.211, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.99it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 94
# train_batch (Avg. Loss 131.175, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.38it/s]
# test_batch (Avg. Loss 146.048, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.35it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 95
# train_batch (Avg. Loss 131.829, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.48it/s]
# test_batch (Avg. Loss 149.720, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.24it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 96
# train_batch (Avg. Loss 132.101, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.41it/s]
# test_batch (Avg. Loss 148.032, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.88it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 97
# train_batch (Avg. Loss 131.717, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.43it/s]
# test_batch (Avg. Loss 146.514, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.88it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 98
# train_batch (Avg. Loss 129.410, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.41it/s]
# test_batch (Avg. Loss 150.154, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.53it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 99
# train_batch (Avg. Loss 129.421, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.32it/s]
# test_batch (Avg. Loss 150.126, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 36.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 100
# --- EPOCH 101/200 ---
# train_batch (Avg. Loss 129.177, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.35it/s]
# test_batch (Avg. Loss 154.794, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.99it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 101
# train_batch (Avg. Loss 129.934, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.36it/s]
# test_batch (Avg. Loss 147.732, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.65it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 102
# train_batch (Avg. Loss 126.668, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.48it/s]
# test_batch (Avg. Loss 142.224, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.46it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 103
# train_batch (Avg. Loss 127.488, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.43it/s]
# test_batch (Avg. Loss 144.507, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 104
# train_batch (Avg. Loss 127.854, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.36it/s]
# test_batch (Avg. Loss 145.016, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.67it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 105
# train_batch (Avg. Loss 127.398, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.46it/s]
# test_batch (Avg. Loss 145.652, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 36.85it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 106
# train_batch (Avg. Loss 128.707, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.53it/s]
# test_batch (Avg. Loss 143.759, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 107
# train_batch (Avg. Loss 126.276, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.33it/s]
# test_batch (Avg. Loss 141.047, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.67it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 108
# train_batch (Avg. Loss 125.677, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.42it/s]
# test_batch (Avg. Loss 145.065, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.56it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 109
# train_batch (Avg. Loss 128.964, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.35it/s]
# test_batch (Avg. Loss 144.464, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.10it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 110
# --- EPOCH 111/200 ---
# train_batch (Avg. Loss 125.711, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.41it/s]
# test_batch (Avg. Loss 141.852, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.57it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 111
# train_batch (Avg. Loss 126.735, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.45it/s]
# test_batch (Avg. Loss 141.223, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.65it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 112
# train_batch (Avg. Loss 126.296, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.39it/s]
# test_batch (Avg. Loss 146.180, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.11it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 113
# train_batch (Avg. Loss 126.076, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.37it/s]
# test_batch (Avg. Loss 142.598, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.57it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 114
# train_batch (Avg. Loss 124.916, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.39it/s]
# test_batch (Avg. Loss 141.862, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.11it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 115
# train_batch (Avg. Loss 125.490, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.35it/s]
# test_batch (Avg. Loss 143.557, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 41.28it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 116
# train_batch (Avg. Loss 125.160, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.39it/s]
# test_batch (Avg. Loss 144.364, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 117
# train_batch (Avg. Loss 125.149, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.00it/s]
# test_batch (Avg. Loss 146.582, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.14it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 118
# train_batch (Avg. Loss 123.750, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.45it/s]
# test_batch (Avg. Loss 142.704, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.15it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 119
# train_batch (Avg. Loss 124.576, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.38it/s]
# test_batch (Avg. Loss 141.924, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 120
# --- EPOCH 121/200 ---
# train_batch (Avg. Loss 124.981, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.39it/s]
# test_batch (Avg. Loss 147.586, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 121
# train_batch (Avg. Loss 123.560, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.42it/s]
# test_batch (Avg. Loss 142.317, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.57it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 122
# train_batch (Avg. Loss 122.383, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.30it/s]
# test_batch (Avg. Loss 145.258, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.33it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 123
# train_batch (Avg. Loss 124.364, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.08it/s]
# test_batch (Avg. Loss 140.841, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.46it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 124
# train_batch (Avg. Loss 122.490, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.41it/s]
# test_batch (Avg. Loss 147.030, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 41.04it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 125
# train_batch (Avg. Loss 123.458, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.17it/s]
# test_batch (Avg. Loss 144.799, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.56it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 126
# train_batch (Avg. Loss 123.999, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.43it/s]
# test_batch (Avg. Loss 144.223, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.79it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 127
# train_batch (Avg. Loss 124.193, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.37it/s]
# test_batch (Avg. Loss 142.478, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.57it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 128
# train_batch (Avg. Loss 122.778, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.38it/s]
# test_batch (Avg. Loss 138.435, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.83it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 129
# train_batch (Avg. Loss 122.284, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.42it/s]
# test_batch (Avg. Loss 139.776, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 130
# --- EPOCH 131/200 ---
# train_batch (Avg. Loss 121.716, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.38it/s]
# test_batch (Avg. Loss 142.990, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.14it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 131
# train_batch (Avg. Loss 121.357, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.32it/s]
# test_batch (Avg. Loss 144.911, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.11it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 132
# train_batch (Avg. Loss 121.961, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.32it/s]
# test_batch (Avg. Loss 144.778, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.11it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 133
# train_batch (Avg. Loss 121.938, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 15.93it/s]
# test_batch (Avg. Loss 140.495, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 134
# train_batch (Avg. Loss 120.870, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.27it/s]
# test_batch (Avg. Loss 144.110, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.81it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 135
# train_batch (Avg. Loss 120.712, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.27it/s]
# test_batch (Avg. Loss 142.133, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 136
# train_batch (Avg. Loss 119.973, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.36it/s]
# test_batch (Avg. Loss 143.511, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.57it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 137
# train_batch (Avg. Loss 120.563, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.33it/s]
# test_batch (Avg. Loss 140.416, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 138
# train_batch (Avg. Loss 119.932, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.19it/s]
# test_batch (Avg. Loss 142.585, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 139
# train_batch (Avg. Loss 118.772, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.30it/s]
# test_batch (Avg. Loss 143.092, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.65it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 140
# --- EPOCH 141/200 ---
# train_batch (Avg. Loss 120.873, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.33it/s]
# test_batch (Avg. Loss 140.399, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.99it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 141
# train_batch (Avg. Loss 121.562, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.44it/s]
# test_batch (Avg. Loss 141.821, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 36.84it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 142
# train_batch (Avg. Loss 120.531, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.19it/s]
# test_batch (Avg. Loss 143.245, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.99it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 143
# train_batch (Avg. Loss 119.126, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.33it/s]
# test_batch (Avg. Loss 139.608, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.34it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 144
# train_batch (Avg. Loss 118.840, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.36it/s]
# test_batch (Avg. Loss 142.561, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.99it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 145
# train_batch (Avg. Loss 118.744, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.35it/s]
# test_batch (Avg. Loss 141.046, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 146
# train_batch (Avg. Loss 119.758, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.39it/s]
# test_batch (Avg. Loss 142.750, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.99it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 147
# train_batch (Avg. Loss 118.800, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.40it/s]
# test_batch (Avg. Loss 139.472, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 41.05it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 148
# train_batch (Avg. Loss 118.983, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.34it/s]
# test_batch (Avg. Loss 140.577, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 41.04it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 149
# train_batch (Avg. Loss 118.151, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.38it/s]
# test_batch (Avg. Loss 141.832, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 41.03it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 150
# --- EPOCH 151/200 ---
# train_batch (Avg. Loss 118.598, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.33it/s]
# test_batch (Avg. Loss 139.866, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.74it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 151
# train_batch (Avg. Loss 119.332, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.37it/s]
# test_batch (Avg. Loss 143.811, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.33it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 152
# train_batch (Avg. Loss 118.920, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.45it/s]
# test_batch (Avg. Loss 142.087, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.15it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 153
# train_batch (Avg. Loss 117.062, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.31it/s]
# test_batch (Avg. Loss 140.719, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.15it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 154
# train_batch (Avg. Loss 116.377, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.41it/s]
# test_batch (Avg. Loss 139.712, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.95it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 155
# train_batch (Avg. Loss 117.060, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.35it/s]
# test_batch (Avg. Loss 139.600, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 41.04it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 156
# train_batch (Avg. Loss 117.749, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.27it/s]
# test_batch (Avg. Loss 140.961, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.00it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 157
# train_batch (Avg. Loss 116.005, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.38it/s]
# test_batch (Avg. Loss 138.336, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.54it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 158
# train_batch (Avg. Loss 118.655, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.39it/s]
# test_batch (Avg. Loss 154.859, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.15it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 159
# train_batch (Avg. Loss 116.609, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.41it/s]
# test_batch (Avg. Loss 141.715, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.88it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 160
# --- EPOCH 161/200 ---
# train_batch (Avg. Loss 116.914, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.40it/s]
# test_batch (Avg. Loss 144.176, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.64it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 161
# train_batch (Avg. Loss 116.277, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.03it/s]
# test_batch (Avg. Loss 140.098, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.15it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 162
# train_batch (Avg. Loss 116.869, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.07it/s]
# test_batch (Avg. Loss 142.149, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.35it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 163
# train_batch (Avg. Loss 116.894, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.08it/s]
# test_batch (Avg. Loss 143.169, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 164
# train_batch (Avg. Loss 115.328, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.32it/s]
# test_batch (Avg. Loss 145.752, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.43it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 165
# train_batch (Avg. Loss 116.560, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.46it/s]
# test_batch (Avg. Loss 139.201, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.66it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 166
# train_batch (Avg. Loss 114.750, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.35it/s]
# test_batch (Avg. Loss 141.586, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.81it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 167
# train_batch (Avg. Loss 114.747, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.35it/s]
# test_batch (Avg. Loss 147.658, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.57it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 168
# train_batch (Avg. Loss 116.185, Accuracy 0.1): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.31it/s]
# test_batch (Avg. Loss 142.667, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.67it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 169
# train_batch (Avg. Loss 115.034, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.49it/s]
# test_batch (Avg. Loss 141.952, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.14it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 170
# --- EPOCH 171/200 ---
# train_batch (Avg. Loss 114.714, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.34it/s]
# test_batch (Avg. Loss 140.712, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 171
# train_batch (Avg. Loss 115.026, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.35it/s]
# test_batch (Avg. Loss 138.549, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 35.82it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 172
# train_batch (Avg. Loss 115.118, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.40it/s]
# test_batch (Avg. Loss 139.880, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 36.57it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 173
# train_batch (Avg. Loss 114.531, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.23it/s]
# test_batch (Avg. Loss 137.803, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 36.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 174
# train_batch (Avg. Loss 113.722, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.31it/s]
# test_batch (Avg. Loss 138.858, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 175
# train_batch (Avg. Loss 113.805, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.37it/s]
# test_batch (Avg. Loss 140.737, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 36.83it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 176
# train_batch (Avg. Loss 113.503, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.41it/s]
# test_batch (Avg. Loss 142.279, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.88it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 177
# train_batch (Avg. Loss 112.360, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.36it/s]
# test_batch (Avg. Loss 139.710, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 41.78it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 178
# train_batch (Avg. Loss 113.446, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.38it/s]
# test_batch (Avg. Loss 139.634, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.25it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 179
# train_batch (Avg. Loss 113.128, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.36it/s]
# test_batch (Avg. Loss 139.608, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.65it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 180
# --- EPOCH 181/200 ---
# train_batch (Avg. Loss 113.919, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.42it/s]
# test_batch (Avg. Loss 141.990, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 41.04it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 181
# train_batch (Avg. Loss 113.330, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.25it/s]
# test_batch (Avg. Loss 139.062, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 41.05it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 182
# train_batch (Avg. Loss 112.288, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.37it/s]
# test_batch (Avg. Loss 140.320, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 183
# train_batch (Avg. Loss 113.261, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.40it/s]
# test_batch (Avg. Loss 139.948, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.88it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 184
# train_batch (Avg. Loss 112.118, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.34it/s]
# test_batch (Avg. Loss 142.271, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.11it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 185
# train_batch (Avg. Loss 111.876, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.31it/s]
# test_batch (Avg. Loss 140.381, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.30it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 186
# train_batch (Avg. Loss 112.056, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.38it/s]
# test_batch (Avg. Loss 138.941, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.23it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 187
# train_batch (Avg. Loss 112.812, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.48it/s]
# test_batch (Avg. Loss 141.418, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.95it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 188
# train_batch (Avg. Loss 112.643, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.41it/s]
# test_batch (Avg. Loss 141.508, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.92it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 189
# train_batch (Avg. Loss 110.997, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.23it/s]
# test_batch (Avg. Loss 139.687, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.65it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 190
# --- EPOCH 191/200 ---
# train_batch (Avg. Loss 111.833, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.24it/s]
# test_batch (Avg. Loss 139.932, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.57it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 191
# train_batch (Avg. Loss 112.334, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.32it/s]
# test_batch (Avg. Loss 141.610, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.25it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 192
# train_batch (Avg. Loss 111.090, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.37it/s]
# test_batch (Avg. Loss 138.782, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 41.53it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 193
# train_batch (Avg. Loss 110.196, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.37it/s]
# test_batch (Avg. Loss 140.946, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 40.11it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 194
# train_batch (Avg. Loss 110.372, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.42it/s]
# test_batch (Avg. Loss 139.169, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.35it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 195
# train_batch (Avg. Loss 110.664, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.47it/s]
# test_batch (Avg. Loss 137.715, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.21it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 196
# train_batch (Avg. Loss 110.619, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.47it/s]
# test_batch (Avg. Loss 142.707, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 36.94it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 197
# train_batch (Avg. Loss 110.047, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.42it/s]
# test_batch (Avg. Loss 138.547, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 38.25it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 198
# train_batch (Avg. Loss 109.611, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.33it/s]
# test_batch (Avg. Loss 142.041, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 39.65it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 199
# --- EPOCH 200/200 ---
# train_batch (Avg. Loss 109.782, Accuracy 0.2): 100%|███████████████████████████████████| 60/60 [00:03<00:00, 16.44it/s]
# test_batch (Avg. Loss 138.502, Accuracy 0.1): 100%|██████████████████████████████████████| 7/7 [00:00<00:00, 37.77it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 200
# *** Images Generated from best model:

# %% [markdown]
# ## Questions
# <a id=part2_7></a>

# %% [markdown]
# **TODO** Answer the following questions. Write your answers in the appropriate variables in the module `hw3/answers.py`.

# %%
from cs236781.answers import display_answer
import hw3.answers

# %% [markdown]
# ### Question 1
#
# What does the $\sigma^2$ hyperparameter (`x_sigma2` in the code) do? Explain the effect of low and high values.

# %%
display_answer(hw3.answers.part2_q1)
# Out:
# The $\sigma^2$ in the VAE model represents the variance in the normal distribution.
# Generally, if $\sigma^2$ will have too big of a value, we will have to take a very large number of samples to find
# out the true expectation. When the variance is so high, using it to learn different models becomes hard.
# In good practices using VAE, we prefer a low-variance gradient estimator based on the reparametrization trick.
# And so in general, in different examples we've seen, high variance tends to be worse and low variance tends to
# be better, so we need to lower the value, but making sure it is not becoming too low.

# %% [markdown]
# ### Question 2
#
# 1. Explain the purpose of both parts of the VAE loss term - reconstruction loss and KL divergence loss.
# 2. How is the latent-space distribution affected by the KL loss term?
# 3. What's the benefit of this effect?

# %%
display_answer(hw3.answers.part2_q2)
# Out:
# 1.  In the first place, we want encodings that are as close as possible to each other while maintaining being distinct
#     from each other. This allows smooth interpolation and the generation of samples.
#     The KL divergence loss's purpose is to ensure this, while the divergence value between two probability
#     distributions measures how much they are different from each other.
#     By minimizing this loss we are optimizing the prob. dist. parameters (among them - $\sigma$) to be as close as it
#     can to the target dist.
#     Regarding the reconstruction loss, it is usually either the MSE or CE loss between the output and the input.
#     Its purpose is to penalize the network for creating outputs that are different from the input.
#
# 2.  The KL divergence encourages the encoder to distribute all input encodings in an even manner around the center
#     of the latent space. If it clusters them apart into specific regions and away from the center, it will get a penalty.
#
# 3.  The benefit of all the input encodings being evenly distributed around the center of the latent space is that unlike
#     when the encodings are densely placed randomly near the center of the latent space, where the decoder finds it
#     very hard to decode anything meaningful from the space, when the two losses are optimized together we maintain the
#     similarity of nearby encodings locally, and globally it is densely packed near the center of the latent space.
#     And then when we reach the equilibrium of the two losses, then when randomly generating a sample (sampling a vector from
#     the same prior dist.), the decoder can successfully decode it, with no gaps between clusters and a smooth mix of features.

# %% [markdown]
# ### Question 3
#
# In the formulation of the VAE loss, why do we start by maximizing the evidence
# distribution, $p(\bb{X})$?

# %%
display_answer(hw3.answers.part2_q3)
# Out:
# Maximizing the evidence distribution is crucial for making the output sample as close to the dataset as we can get.
# Maximizing it will result in decoding output to be as close to the dataset with high probability.
# So our expectation is that our whole encoding - decoding system will work better if we maximize the evidence distribution.

# %% [markdown]
# ### Question 4
#
# In the VAE encoder, why do we model the **log** of the
# latent-space variance corresponding to an input, $\bb{\sigma}^2_{\bb{\alpha}}$,
# instead of directly modelling this variance?

# %%
display_answer(hw3.answers.part2_q4)
# Out:
# Modeling the log of the latent-space variance instead of using the variance has the following pros:
#
# 1.  $\bb{\sigma}^2_{\bb{\alpha}}$ is a positive value by definition and the $log(\bb{\sigma}^2)$ will output positive value.
#
# 2.  We get numerical stability because we map small values in the interval [0,1] to (-inf, log(1)] so we get better numerical stability due to that mapping.
#     Furthermore $\bb{\sigma}^2_{\bb{\alpha}}$ is a relatively small value 1>>$\bb{\sigma}^2_{\bb{\alpha}}$>0.
