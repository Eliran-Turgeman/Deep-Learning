# %% [markdown]
# $$
# \newcommand{\mat}[1]{\boldsymbol {#1}}
# \newcommand{\mattr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\matinv}[1]{\boldsymbol {#1}^{-1}}
# \newcommand{\vec}[1]{\boldsymbol {#1}}
# \newcommand{\vectr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\rvar}[1]{\mathrm {#1}}
# \newcommand{\rvec}[1]{\boldsymbol{\mathrm{#1}}}
# \newcommand{\diag}{\mathop{\mathrm {diag}}}
# \newcommand{\set}[1]{\mathbb {#1}}
# \newcommand{\cset}[1]{\mathcal{#1}}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\pderiv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\bb}[1]{\boldsymbol{#1}}
# \newcommand{\E}[2][]{\mathbb{E}_{#1}\left[#2\right]}
# \newcommand{\ip}[3]{\left<#1,#2\right>_{#3}}
# \newcommand{\given}[]{\,\middle\vert\,}
# \newcommand{\DKL}[2]{\cset{D}_{\text{KL}}\left(#1\,\Vert\, #2\right)}
# \newcommand{\grad}[]{\nabla}
# $$
#
# # Part 3: Mini-Project
# <a id=part3></a>

# %% [markdown]
# In this part you'll implement a small comparative-analysis project, heavily based on the materials from the tutorials and homework.
#
# You must **choose one** of the project options specified below.

# %% [markdown]
# ### Guidelines

# %% [markdown]
# - You should implement the code which displays your results in this notebook, and add any additional code files for your implementation in the `project/` directory. You can import these files here, as we do for the homeworks.
# - Running this notebook should not perform any training - load your results from some output files and display them here. The notebook must be runnable from start to end without errors.
# - You must include a detailed write-up (in the notebook) of what you implemented and how.
# - Explain the structure of your code and how to run it to reproduce your results.
# - Explicitly state any external code you used, including built-in pytorch models and code from the course tutorials/homework.
# - Analyze your numerical results, explaining **why** you got these results (not just specifying the results).
# - Where relevant, place all results in a table or display them using a graph.
# - Before submitting, make sure all files which are required to run this notebook are included in the generated submission zip.
# - Try to keep the submission file size under 10MB. Do not include model checkpoint files, dataset files, or any other non-essentials files. Instead include your results as images/text files/pickles/etc, and load them for display in this notebook.

# %% [markdown]
# ## Sentiment Analysis with Self-Attention and Word Embeddings

# %% [markdown]
# Based on Tutorials 6 and 7, we'll implement and train an improved sentiment analysis model.
# We'll use self-attention instead of RNNs and incorporate pre-trained word embeddings.
#
# In tutorial 6 we saw that we can train word embeddings together with the model.
# Although this produces embeddings which are customized to the specific task at hand,
# it also greatly increases training time.
# A common technique is to use pre-trained word embeddings.
# This is essentially a large mapping from words (e.g. in english) to some
# high-dimensional vector, such that semantically similar words have an embedding that is
# "close" by some metric (e.g. cosine distance).
# Use the [GloVe](https://nlp.stanford.edu/projects/glove/) 6B embeddings for this purpose.
# You can load these vectors into the weights of an `nn.Embedding` layer.
#
# In tutorial 7 we learned how attention can be used to learn to predict a relative importance
# for each element in a sequence, compared to the other elements.
# Here, we'll replace the RNN with self-attention only approach similar to Transformer models, roughly based on [this paper](https://www.aclweb.org/anthology/W18-6219.pdf).
# After embedding each word in the sentence using the pre-trained word-embedding a positional-encoding vector is added to provide each word in the sentence a unique value based on it's location.
# One or more self-attention layers are then applied to the results, to obtain an importance weighting for each word.
# Then we classify the sentence based on the average these weighted encodings.
#
#
# Now, using these approaches, you need to:
#
# - Implement a **baseline** model: Use pre-trained embeddings with an RNN-based model.
# You can use LSTM/GRU or bi-directional versions of these, in a way very similar to what we implemented in the tutorial.
# -  Implement an **improved** model: Based on the self-attention approach, implement an attention-based sentiment analysis model that has 1-2 self-attention layers instead of an RNN. You should use the same pre-trained word embeddings for this model.
# - You can use pytorch's built-in RNNs, attention layers, etc.
# - For positional encoding you can use the sinosoidal approach described in the paper (first proposed [here](https://arxiv.org/pdf/1706.03762.pdf)). You can use existing online implementations (even though it's straightforward to implement).
# - You can use the SST database as shown in the tutorial.
#
# Your results should include:
# - Everything written in the **Guidelines** above.
# - A comparative analysis: compare the baseline to the improved model. Compare in terms of overall classification accuracy and show a multiclass confusion matrix.
# - Visualize of the attention maps for a few movie reviews from each class, and explain the results.

# %% [markdown]
# ## Spectrally-Normalized Wasserstein GANs

# %% [markdown]
# In HW3 we implemented a simple GANs from scratch, using an approach very similar to the original GAN paper. However, the results left much to be desired and we discovered first-hand how hard it is to train GANs due to their inherent instability.
#
# One of the prevailing approaches for improving training stability for GANs is to use a technique called [Spectral Normalization](https://arxiv.org/pdf/1802.05957.pdf) to normalize the largest singular value of a weight matrix so that it equals 1.
# This approach is generally applied to the discriminator's weights in order to stabilize training. The resulting model is sometimes referred to as a SN-GAN.
# See Appendix A in the linked paper for the exact algorithm. You can also use pytorch's `spectral_norm`.
#
# Another very common improvement to the vanilla GAN is known a [Wasserstein GAN](https://arxiv.org/pdf/1701.07875.pdf) (WGAN). It uses a simple modification to the loss function, with strong theoretical justifications based on the Wasserstein (earth-mover's) distance.
# See also [here](https://developers.google.com/machine-learning/gan/loss) for a brief explanation of this loss function.
#
# One problem with generative models for images is that it's difficult to objectively assess the quality of the resulting images.
# To also obtain a quantitative score for the images generated by each model,
# we'll use the [Inception Score](https://arxiv.org/pdf/1606.03498.pdf).
# This uses a pre-trained Inception CNN model on the generated images and computes a score based on the predicted probability for each class.
# Although not a perfect proxy for subjective quality, it's commonly used a way to compare generative models.
# You can use an implementation of this score that you find online, e.g. [this one](https://github.com/sbarratt/inception-score-pytorch) or implement it yourself.
#
# Based on the linked papers, add Spectral Normalization and the Wassertein loss to your GAN from HW3.
# Compare between:
# - The baseline model (vanilla GAN)
# - SN-GAN (vanilla + Spectral Normalization)
# - WGAN (using Wasserstein Loss)
# - Optional: SN+WGAN, i.e. a combined model using both modifications.
#
# As a dataset, you can use [LFW](http://vis-www.cs.umass.edu/lfw/) as in HW3 or [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html), or even choose a custom dataset (note that there's a dataloder for CelebA in `torchvision`).
#
# Your results should include:
# - Everything written in the **Guidelines** above.
# - A comparative analysis between the baseline and the other models. Compare:
#   - Subjective quality (show multiple generated images from each model)
#   - Inception score (can use a subset of the data).
# - You should show substantially improved subjective visual results with these techniques.

# %% [markdown]
# ## Implementation

# %% [markdown]
# **TODO**: This is where you should write your explanations and implement the code to display the results.
# See guidelines about what to include in this section.

# %%
from project.notebook import *

# %%
ds_gwb = generateDataSet()

import cs236781.plot as plot
_ = plot.dataset_first_n(ds_gwb, 50, figsize=(15,10), nrows=5)
print(f'Found {len(ds_gwb)} images in dataset folder.')
# Out:
# File /home/elirant/go-here/Deep-Learning/hw4/project/pytorch-datasets/lfw-a.zip exists, skipping download.
# Extracting /home/elirant/go-here/Deep-Learning/hw4/project/pytorch-datasets/lfw-a.zip...
# Extracted 1486 to /home/elirant/go-here/Deep-Learning/hw4/project/pytorch-datasets/lfw/Aaron_Eckhart
# Found 1054 images in dataset folder.

# %%
for _ in range(100):
    generateResults(train=True, num_epochs=100)
# Out:
# File /home/elirant/go-here/Deep-Learning/hw4/project/pytorch-datasets/lfw-a.zip exists, skipping download.
# Extracting /home/elirant/go-here/Deep-Learning/hw4/project/pytorch-datasets/lfw-a.zip...
# Extracted 1486 to /home/elirant/go-here/Deep-Learning/hw4/project/pytorch-datasets/lfw/Aaron_Eckhart
# --- EPOCH 1/100 ---
# 100%|██████████| 33/33 [00:16<00:00,  2.02it/s]
# Vanila-Base-Gan
# Discriminator loss: 8.110914691266688
# Generator loss:     27.193294322851933
# SN-Gan
# Discriminator loss: 2.0702010280255116
# Generator loss:     11.624152414726488
# W-Gan
# Discriminator loss: -11.549378820440985
# Generator loss:     31.08880925178528
# SN-W-Gan
# Discriminator loss: -62.141911463304
# Generator loss:     44.296512654333405
# ========Vanila-Base-Gan========
# ========================
# Loading inception model
# Generating 20000 images in 625 batches:
# 100%|██████████| 625/625 [00:35<00:00, 17.54it/s]
# score forVanila-Base-Gan is mean: 1.0881128564679758 std:0.0008908477071030483
# ========SN-Gan========
# ========================
# Loading inception model
# Generating 20000 images in 625 batches:
# 100%|██████████| 625/625 [00:36<00:00, 17.28it/s]
# score forSN-Gan is mean: 1.1186279514600355 std:0.0017408577234332295
# ========W-Gan========
# ========================
# Loading inception model
# Generating 20000 images in 625 batches:
# 100%|██████████| 625/625 [00:36<00:00, 17.14it/s]
# score forW-Gan is mean: 1.1487753500548887 std:0.0009203856565391123
# ========SN-W-Gan========
# ========================
# Loading inception model
# Generating 20000 images in 625 batches:
#   0%|          | 0/625 [00:00<?, ?it/s]

# %%
generateResults()
# Out:
# Generating Results
# =====================================
# Model Type: Vanila-Base-Gan
# Generated Images:
# =====================================
# =====================================
# Model Type: SN-Gan
# Generated Images:
# =====================================
# =====================================
# Model Type: W-Gan
# Generated Images:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-22430392608e> in <module>
# ----> 1 generateResults()
#
# ~/go-here/Deep-Learning/hw4/project/notebook.py in generateResults(train, num_epochs)
#      51     for name in ganModelNames:
#      52             modelPath = resultsDirPath + name
# ---> 53             generateResultsFromPath(name, modelPath)
#      54     print('Inception Score Comparison:')
#      55     plotScore(resultsDirPath, ganModelNames, num_epochs)
#
# ~/go-here/Deep-Learning/hw4/project/notebook.py in generateResultsFromPath(modelName, modelPath)
#     188     print(f'Generated Images: ')
#     189     samples = torch.load(f'{modelPath}/generated_samples.pt')
# --> 190     fig, _ = plot.tensors_as_images(samples.cpu(), figsize=(15,10), nrows=5)
#     191     IPython.display.display(fig)
#     192     plt.close(fig)
#
# ~/go-here/Deep-Learning/hw4/cs236781/plot.py in tensors_as_images(tensors, nrows, figsize, titles, wspace, hspace, cmap)
#      21     ncols = math.ceil(num_tensors / nrows)
#      22
# ---> 23     fig, axes = plt.subplots(
#      24         nrows=nrows,
#      25         ncols=ncols,
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1286     """
#    1287     fig = figure(**fig_kw)
# -> 1288     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1289                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1290                        gridspec_kw=gridspec_kw)
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1520         if gridspec_kw is None:
#    1521             gridspec_kw = {}
# -> 1522         return (self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#    1523                 .subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#    1524                           subplot_kw=subplot_kw))
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/gridspec.py in subplots(self, sharex, sharey, squeeze, subplot_kw)
#     334                 subplot_kw["sharex"] = shared_with[sharex]
#     335                 subplot_kw["sharey"] = shared_with[sharey]
# --> 336                 axarr[row, col] = figure.add_subplot(
#     337                     self[row, col], **subplot_kw)
#     338
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
# ---> 42         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      43         # add a layout box to this, for both the full axis, and the poss
#      44         # of the axis.  We need both because the axes may become smaller
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     509
#     510         self._rasterization_zorder = None
# --> 511         self.cla()
#     512
#     513         # funcs used to format x and y - fall back on major formatters
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/axes/_base.py in cla(self)
#    1160
#    1161         self.xaxis.set_clip_path(self.patch)
# -> 1162         self.yaxis.set_clip_path(self.patch)
#    1163
#    1164         self._shared_x_axes.clean()
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/axis.py in set_clip_path(self, clippath, transform)
#     899     def set_clip_path(self, clippath, transform=None):
#     900         martist.Artist.set_clip_path(self, clippath, transform)
# --> 901         for child in self.majorTicks + self.minorTicks:
#     902             child.set_clip_path(clippath, transform)
#     903         self.stale = True
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     621             else:
#     622                 instance.minorTicks = []
# --> 623                 tick = instance._get_tick(major=False)
#     624                 instance.minorTicks.append(tick)
#     625                 return instance.minorTicks
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2304         else:
#    2305             tick_kw = self._minor_tick_kw
# -> 2306         return YTick(self.axes, 0, major=major, **tick_kw)
#    2307
#    2308     def set_label_position(self, position):
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     490         super().__init__(*args, **kwargs)
#     491         # x in axes coords, y in data coords
# --> 492         self.tick1line.set(
#     493             xdata=[0], ydata=[0],
#     494             transform=self.axes.get_yaxis_transform(which="tick1"),
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1086     def set(self, **kwargs):
#    1087         """A property batch setter.  Pass *kwargs* to set properties."""
# -> 1088         kwargs = cbook.normalize_kwargs(kwargs, self)
#    1089         move_color_to_start = False
#    1090         if "color" in kwargs:
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     397         # We cannot just check `name not in arguments` because the pyplot
#     398         # wrappers always pass all arguments explicitly.
# --> 399         elif any(name in d and d[name] != _deprecated_parameter
#     400                  for d in [arguments, arguments.get(kwargs_name, {})]):
#     401             deprecation_addendum = (
#
# ~/miniconda3/envs/cs236781-hw/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py in <genexpr>(.0)
#     397         # We cannot just check `name not in arguments` because the pyplot
#     398         # wrappers always pass all arguments explicitly.
# --> 399         elif any(name in d and d[name] != _deprecated_parameter
#     400                  for d in [arguments, arguments.get(kwargs_name, {})]):
#     401             deprecation_addendum = (
#
# KeyboardInterrupt:
